# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://meesho.com/bags-ladies/pl/p7vbp')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
first_title = soup.find(class_="Card__BaseCard-sc-b3n78k-0 dUNFgg NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS")
first_title
# Out:
# <div class="Card__BaseCard-sc-b3n78k-0 dUNFgg NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS" color="white"><p class="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS" color="greyT2" font-size="16px" font-weight="book">Elite Fancy Women Handbags</p><div class="Card__BaseCard-sc-b3n78k-0 iLPHgK NewProductCard__PriceRow-sc-j0e7tu-5 eyya-Dr NewProductCard__PriceRow-sc-j0e7tu-5 eyya-Dr" color="white"><h5 class="Text__StyledText-sc-oo0kvp-0 hiHdyy" color="greyBase" font-size="24px" font-weight="bold">₹<!-- -->245</h5><p class="Text__StyledText-sc-oo0kvp-0 hpXvds Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0 hEkmRy Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0 hEkmRy" color="greyT2" font-size="16px" font-weight="book">₹<!-- -->345</p><span class="Text__StyledText-sc-oo0kvp-0 lnonyH" color="greenBase" font-size=
# ...

# %%
first_title.text
# Out:
# 'Elite Fancy Women Handbags₹245₹34529% off₹100 discount on 1st orderFree Delivery2.53 Reviews'

# %%
titles = []

for i in soup.find_all('div',class_="Card__BaseCard-sc-b3n78k-0 dUNFgg NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS"):
    titles.append(i.text)
    
titles
# Out:
# ['Elite Fancy Women Handbags₹245₹34529% off₹100 discount on 1st orderFree Delivery2.53 Reviews',
#  'Gorgeous Classy Women Handbags₹193₹27530% off₹82 discount on 1st orderFree Delivery3.818 Reviews',
#  "Elegant Fancy Women'S Pu Leather Hand Bags₹175₹25030% off₹75 discount on 1st orderFree Delivery4.02694 Reviews",
#  "Elegant Fancy Women's Bags₹189₹26930% off₹80 discount on 1st orderFree Delivery4.01164 Reviews",
#  'Voguish Fashionable Women Handbags₹254₹35428% off₹100 discount on 1st orderFree Delivery3.631 Reviews',
#  'Gorgeous Stylish Women Handbags₹150₹21330% off₹63 discount on 1st orderFree Delivery3.6Supplier',
#  'Gorgeous Attractive Women Handbags₹196₹28030% off₹84 discount on 1st orderFree Delivery3.553 Reviews',
#  'Elite Fancy Women Handbags₹140₹20030% off₹60 discount on 1st orderFree Delivery3.8519 Reviews',
#  'Classic Stylish Women Handbags₹250₹35029% off₹100 discount on 1st orderFree Delivery3.37 Reviews',
# ...

# %%
price = []

for i in soup.find_all('div',class_="Card__BaseCard-sc-b3n78k-0 iLPHgK NewProductCard__PriceRow-sc-j0e7tu-5 eyya-Dr NewProductCard__PriceRow-sc-j0e7tu-5 eyya-Dr"):
    price.append(i.text)
    
price
# Out:
# ['₹245₹34529% off',
#  '₹193₹27530% off',
#  '₹175₹25030% off',
#  '₹189₹26930% off',
#  '₹254₹35428% off',
#  '₹150₹21330% off',
#  '₹196₹28030% off',
#  '₹140₹20030% off',
#  '₹250₹35029% off',
#  '₹197₹28130% off',
#  '₹260₹36028% off',
#  '₹217₹31030% off',
#  '₹182₹25930% off',
#  '₹207₹29530% off',
#  '₹210₹29930% off',
#  '₹204₹29130% off',
#  '₹517₹61716% off',
#  '₹133₹18930% off',
#  '₹185₹26430% off',
#  '₹211₹30130% off']

# %%
discount = []

for i in soup.find_all('div',class_="Card__BaseCard-sc-b3n78k-0 iJCKg NewProductCard__DiscountRow-sc-j0e7tu-15 kUcVjG NewProductCard__DiscountRow-sc-j0e7tu-15 kUcVjG"):
    discount.append(i.text)
    
discount
# Out:
# ['₹100 discount on 1st order',
#  '₹82 discount on 1st order',
#  '₹75 discount on 1st order',
#  '₹80 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹63 discount on 1st order',
#  '₹84 discount on 1st order',
#  '₹60 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹84 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹93 discount on 1st order',
#  '₹77 discount on 1st order',
#  '₹88 discount on 1st order',
#  '₹89 discount on 1st order',
#  '₹87 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹56 discount on 1st order',
#  '₹79 discount on 1st order',
#  '₹90 discount on 1st order']

# %%
import pandas as pd
df = pd.DataFrame({'titles':titles,'price':price,'discount':discount})
df
# Out:
#                                                titles            price  \
# 0   Elite Fancy Women Handbags₹245₹34529% off₹100 ...  ₹245₹34529% off
# 1   Gorgeous Classy Women Handbags₹193₹27530% off₹...  ₹193₹27530% off
# 2   Elegant Fancy Women'S Pu Leather Hand Bags₹175...  ₹175₹25030% off
# 3   Elegant Fancy Women's Bags₹189₹26930% off₹80 d...  ₹189₹26930% off
# 4   Voguish Fashionable Women Handbags₹254₹35428% ...  ₹254₹35428% off
# 5   Gorgeous Stylish Women Handbags₹150₹21330% off...  ₹150₹21330% off
# 6   Gorgeous Attractive Women Handbags₹196₹28030% ...  ₹196₹28030% off
# 7   Elite Fancy Women Handbags₹140₹20030% off₹60 d...  ₹140₹20030% off
# 8   Classic Stylish Women Handbags₹250₹35029% off₹...  ₹250₹35029% off
# 9   Attractive Women Handbags₹197₹28130% off₹84 di...  ₹197₹28130% off
# 10  Elite Fancy Women Handbags₹260₹36028% off₹100 ...  ₹260₹36028% off
# 11  Wonderful Women Women Handbags₹217₹31030% off₹...  ₹217₹31030% off
# ...
